# %% [markdown]
# ## Paquetes

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# Urilizar esto si se instaló tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# # Utilizar esto si se instaló Keras
# from keras.models import Sequential
# from keras.layers import Dense

# %% [markdown]
# ## Problema

# %% [markdown]
# Como introducción a las redes neuronales artificiales para resolver problemas de clasificación, se intentará resolver un problema linealmente separable como lo es la compuerta lógica AND

# %% [markdown]
# ### Compuerta Lógica AND

# %% [markdown]
# <img src="attachment:image.png" width="600">

# %% [markdown]
# Para esto, se necesita recrear el dataset de casos para la compuerta específica (en este caso, son los datos de la tabla de verdad)

# %%
x_train = np.array([[0,0], [0,1], [1,0], [1,1]])
y_train = np.array([[0], [0], [0], [1]])

# %% [markdown]
# Ahora procedemos a inicializar un variable con un tipo especial de variable SEQUENTIAL

# %%
model = Sequential()

# %% [markdown]
# Con la función "add" vamos a añadir capas a nuestro modelo. Recuerde que en la primera capa debe especificar cual es el número de datos de entrada.
# Como ejemplo, vamos a crear una red neuronal que tenga 3 neurona en su capa oculta y 1 una neurona en su capa de salida.

# %%
model.add(None)
model.add(None)

# %% [markdown]
# Luego, por último, debemos compilar nuestro modelo, seleccionando la función a optimizar, la función optimizadora y las métricas a visualizar.

# %%
model.compile(None)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 10)                30
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# ...
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Listo. Ahora solo necesitamos entrenar nuestro modelo con la función "fit".

# %%
history = model.fit(None)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6355 - accuracy: 0.7500
# Epoch 2/1000
# 1/1 [==============================] - 0s 996us/step - loss: 0.6349 - accuracy: 0.7500
# Epoch 3/1000
# 1/1 [==============================] - 0s 0s/step - loss: 0.6341 - accuracy: 0.7500
# Epoch 4/1000
# 1/1 [==============================] - 0s 998us/step - loss: 0.6334 - accuracy: 0.7500
# Epoch 5/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6327 - accuracy: 0.7500
# Epoch 6/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6320 - accuracy: 0.7500
# Epoch 7/1000
# 1/1 [==============================] - 0s 986us/step - loss: 0.6313 - accuracy: 0.7500
# Epoch 8/1000
# 1/1 [==============================] - 0s 992us/step - loss: 0.6306 - accuracy: 0.7500
# Epoch 9/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6299 - accuracy: 0.7500
# Epoch 10/1000
# ...

# %% [markdown]
# Veamos visualmente los resultados

# %%
plt.plot(history.history['accuracy'])
plt.title('Exactitud del Modelo')
plt.ylabel('Exactitud')
plt.xlabel('Épocas')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.title('Función de Pérdida del Modelo')
plt.ylabel('Función de Pérdida')
plt.xlabel('Épocas')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# ## Problema de Iris Dataset (Clasificación de flores)

# %% [markdown]
# Primero, descargamos el dataset de iris y separamos los datos en diferentes variables

# %%
iris = load_iris()
X = iris['data']
y = iris['target']
names = iris['target_names']
feature_names = iris['feature_names']

# %% [markdown]
# Imprimimos los nombres objetivos (nuestras tres categorias)

# %%
None
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# Impriminos los nombres nuestras características

# %%
None
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %% [markdown]
# <img src="attachment:image.png" width="400">

# %% [markdown]
# Lo primero que necesitamos hacer es convertir nuestra variable objetivo a un variable dummy. Esto es posible utlizando una compensión llamada OneHotEncoder.

# %%
# One hot encoding
enc = OneHotEncoder()
Y = None

# %%
Y[:5]
# Out:
# array([0., 0., 1.])

# %% [markdown]
# Luego reescalamos los datos para ayudar al optimizador converger aún más rápido y evitar errores futuros con nuestros datos de entrada.

# %%
scaler = StandardScaler()
X_scaled = None

# %% [markdown]
# Después, dividimos el dataset en un conjunto de entranamiento y un conjunto de testeo

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.5, random_state=2)

n_features = X.shape[1]
n_classes = Y.shape[1]

# %% [markdown]
# Por último, solo queda crear nuestro modelo y entrenarlo. Para este caso, vamos a crear un modelo con la siguiente forma:
#
# **Entrada (4) -> Oculta (8) -> Oculta (16) -> Oculta (8) -> Salida (3)**

# %%
model = Sequential()
model.add(None)
model.add(None)
model.add(None)
model.add(None)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train,
                    batch_size=8,
                    epochs=50,
                    verbose=1,
                    validation_data=(X_test, Y_test))
# Out:
# Epoch 1/50
# 10/10 [==============================] - 0s 17ms/step - loss: 0.6549 - accuracy: 0.2000 - val_loss: 0.6563 - val_accuracy: 0.2400
# Epoch 2/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6424 - accuracy: 0.3067 - val_loss: 0.6478 - val_accuracy: 0.3067
# Epoch 3/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6337 - accuracy: 0.3600 - val_loss: 0.6412 - val_accuracy: 0.3067
# Epoch 4/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6267 - accuracy: 0.3600 - val_loss: 0.6355 - val_accuracy: 0.3067
# Epoch 5/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6208 - accuracy: 0.3600 - val_loss: 0.6307 - val_accuracy: 0.3067
# Epoch 6/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6148 - accuracy: 0.3600 - val_loss: 0.6256 - val_accuracy: 0.3200
# Epoch 7/50
# ...

# %% [markdown]
# Para esto, utilizaremos la función evaluate para evaluar los resultados de nuestro modelo

# %%
score = model.evaluate(X_test, Y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.18519987165927887
# Test accuracy: 0.9066666960716248

# %% [markdown]
# Por último, graficaremos

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Exactitud del Modelo')
plt.ylabel('Exactitud')
plt.xlabel('Épocas')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Función de Pérdida del Modelo')
plt.ylabel('Función de Pérdida')
plt.xlabel('Épocas')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
